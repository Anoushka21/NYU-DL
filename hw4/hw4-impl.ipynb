# %% [markdown]
# ## Vision Transformer (ViT)
#
# In this assignment we're going to work with Vision Transformer. We will start to build our own vit model and train it on an image classification task.
# The purpose of this homework is for you to get familar with ViT and get prepared for the final project.

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# # VIT Implementation
#
# The vision transformer can be seperated into three parts, we will implement each part and combine them in the end.
#
# For the implementation, feel free to experiment different kinds of setup, as long as you use attention as the main computation unit and the ViT can be train to perform the image classification task present later.
# You can read about the ViT implement from other libary: https://github.com/huggingface/pytorch-image-models/blob/main/timm/models/vision_transformer.py and https://github.com/pytorch/vision/blob/main/torchvision/models/vision_transformer.py

# %% [markdown]
# ## PatchEmbedding
# PatchEmbedding is responsible for dividing the input image into non-overlapping patches and projecting them into a specified embedding dimension. It uses a 2D convolution layer with a kernel size and stride equal to the patch size. The output is a sequence of linear embeddings for each patch.

# %%
class PatchEmbedding(nn.Module):
    def __init__(self, image_size, patch_size, in_channels, embed_dim):
        super().__init__()
        self.image_size = image_size
        self.patch_size = patch_size
        self.in_channels = in_channels
        self.embed_dim = embed_dim
        self.num_patches = (image_size // patch_size) ** 2
        self.proj = nn.Conv2d(in_channels, embed_dim, kernel_size=patch_size, stride=patch_size)

    def forward(self, x):
        x = self.proj(x)  
        #print(x.shape)
        x = x.flatten(2)  
        x = x.transpose(1, 2)  
        return x

# %% [markdown]
# ## MultiHeadSelfAttention
#
# This class implements the multi-head self-attention mechanism, which is a key component of the transformer architecture. It consists of multiple attention heads that independently compute scaled dot-product attention on the input embeddings. This allows the model to capture different aspects of the input at different positions. The attention outputs are concatenated and linearly transformed back to the original embedding size.

# %%
class MultiHeadSelfAttention(nn.Module):
    def __init__(self, embed_dim, num_heads):
      # TODO
      super().__init__()
      self.embed_dim = embed_dim
      self.num_heads = num_heads
      self.head_dim = embed_dim // num_heads

      self.query = nn.Linear(embed_dim, embed_dim)
      self.key = nn.Linear(embed_dim, embed_dim)
      self.value = nn.Linear(embed_dim, embed_dim)
      self.proj = nn.Linear(embed_dim, embed_dim)

    def forward(self, x):
      # TODO
      batch_size, seq_len, embed_dim = x.shape
      query = self.query(x).view(batch_size, seq_len, self.num_heads, self.head_dim)
      key = self.key(x).view(batch_size, seq_len, self.num_heads, self.head_dim)
      value = self.value(x).view(batch_size, seq_len, self.num_heads, self.head_dim)

      scores = torch.einsum('bsnd,bsmd->bnsm', query, key) / (self.embed_dim ** 0.5)
      attn_weights = F.softmax(scores, dim=-1)
      attn_output = torch.einsum('bnsm,bsmd->bsnd', attn_weights, value)
      attn_output = attn_output.view(batch_size, seq_len, embed_dim)
      output = self.proj(attn_output) + x
      return output

# %% [markdown]
# ## TransformerBlock
# This class represents a single transformer layer. It includes a multi-head self-attention sublayer followed by a position-wise feed-forward network (MLP). Each sublayer is surrounded by residual connections.
# You may also want to use layer normalization or other type of normalization.

# %%
class TransformerBlock(nn.Module):
    def __init__(self, embed_dim, num_heads, mlp_dim, dropout):
        super().__init__()
        
        self.self_attention = MultiHeadSelfAttention(embed_dim, num_heads)
        self.norm1 = nn.LayerNorm(embed_dim)
        self.dropout1 = nn.Dropout(dropout)
        
        self.mlp = nn.Sequential(
            nn.Linear(embed_dim, mlp_dim),
            nn.GELU(),
            nn.Linear(mlp_dim, embed_dim),
        )
        self.norm2 = nn.LayerNorm(embed_dim)
        self.dropout2 = nn.Dropout(dropout)

    def forward(self, x):
        # TODO
        attn_output = self.self_attention(x)
        attn_output = self.dropout1(attn_output)
        x = self.norm1(x + attn_output)
        mlp_output = self.mlp(x)
        mlp_output = self.dropout2(mlp_output)
        x = self.norm2(x + mlp_output)
        return x

# %% [markdown]
# ## VisionTransformer:
# This is the main class that assembles the entire Vision Transformer architecture. It starts with the PatchEmbedding layer to create patch embeddings from the input image. A special class token is added to the sequence, and positional embeddings are added to both the patch and class tokens. The sequence of patch embeddings is then passed through multiple TransformerBlock layers. The final output is the logits for all classes

# %%
class VisionTransformer(nn.Module):
    def __init__(self, image_size, patch_size, in_channels, embed_dim, num_heads, mlp_dim, num_layers, num_classes, dropout=0.1):
        # TODO
        super(VisionTransformer, self).__init__()

        num_patches = (image_size // patch_size) ** 2
        patch_dim = in_channels * patch_size ** 2
        self.patch_embedding=PatchEmbedding(image_size, patch_size, in_channels, embed_dim)
        self.class_token = nn.Parameter(torch.zeros(1, 1, embed_dim))
        self.positional_embeddings = nn.Parameter(torch.randn(1, num_patches + 1, embed_dim))
        self.transformer_layers = nn.ModuleList([
            TransformerBlock(embed_dim, num_heads, mlp_dim, dropout)
            for _ in range(num_layers)
        ])

        self.fc = nn.Linear(embed_dim, num_classes)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        x = self.patch_embedding(x)
        class_token = self.class_token.expand(x.shape[0], -1, -1)
        x = torch.cat([class_token, x], dim=1)

        pos_embed = self.positional_embeddings[:, :(x.size(1)), :]
        x = x + pos_embed

        for transformer_layer in self.transformer_layers:
            x = transformer_layer(x)

        x = x.mean(dim=1)
        x = self.fc(x)

        return x

# %% [markdown]
# ## Let's train the ViT!
#
# We will train the vit to do the image classification with cifar100. Free free to change the optimizer and or add other tricks to improve the training

# %%
image_size = 64
patch_size = 8
in_channels = 3
embed_dim = 256
num_heads = 8
mlp_dim = 512
num_layers = 6
num_classes = 100
dropout = 0.01
batch_size = 256

# %%
model = VisionTransformer(image_size, patch_size, in_channels, embed_dim, num_heads, mlp_dim, num_layers, num_classes, dropout).to(device)
input_tensor = torch.randn(1, in_channels, image_size, image_size).to(device)
output = model(input_tensor)
print(output.shape)
# Out:
# torch.Size([1, 100])

# %%
# Load the CIFAR-100 dataset
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.Resize(image_size),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.Resize(image_size),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

trainset = datasets.CIFAR100(root='./data', train=True, download=True, transform=transform_train)
testset = datasets.CIFAR100(root='./data', train=False, download=True, transform=transform_test)

trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
#   0%|          | 0/169001437 [00:00<?, ?it/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified

# %%
# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)
#lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.1)
lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100)

# %%
# Train the model
num_epochs = 100
best_val_acc = 0
for epoch in range(num_epochs):
    model.train()
    for i, data in enumerate(trainloader, 0):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        #nn.utils.clip_grad_value_(model.parameters(), clip_value=1.0)
        optimizer.step()
    lr_scheduler.step()

        # TODO Feel free to modify the training loop youself.

    # Validate the model
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    val_acc = 100 * correct / total
    print(f"Epoch: {epoch + 1}, Validation Accuracy: {val_acc:.2f}%")

    # Save the best model
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), "best_model.pth")
# Out:
# Epoch: 1, Validation Accuracy: 10.78%
# Epoch: 2, Validation Accuracy: 14.69%
# Epoch: 3, Validation Accuracy: 21.00%
# Epoch: 4, Validation Accuracy: 23.92%
# Epoch: 5, Validation Accuracy: 28.16%
# Epoch: 6, Validation Accuracy: 31.00%
# Epoch: 7, Validation Accuracy: 33.34%
# Epoch: 8, Validation Accuracy: 35.80%
# Epoch: 9, Validation Accuracy: 37.47%
# Epoch: 10, Validation Accuracy: 39.64%
# Epoch: 11, Validation Accuracy: 40.99%
# Epoch: 12, Validation Accuracy: 41.90%
# Epoch: 13, Validation Accuracy: 43.60%
# Epoch: 14, Validation Accuracy: 44.69%
# Epoch: 15, Validation Accuracy: 46.43%
# Epoch: 16, Validation Accuracy: 45.42%
# Epoch: 17, Validation Accuracy: 46.13%
# Epoch: 18, Validation Accuracy: 47.38%
# Epoch: 19, Validation Accuracy: 48.45%
# Epoch: 20, Validation Accuracy: 48.23%
# Epoch: 21, Validation Accuracy: 49.51%
# Epoch: 22, Validation Accuracy: 49.87%
# Epoch: 23, Validation Accuracy: 49.45%
# Epoch: 24, Validation Accuracy: 51.19%
# Epoch: 25, Validation Accuracy: 51.57%
# Epoch: 26, Validation Accuracy: 52.07%
# Epoch: 27, Validation Accuracy: 52.09%
# Epoch: 28, Validation Accuracy: 52.99%
# Epoch: 29, Validation Accuracy: 53.29%
# Epoch: 30, Validation Accuracy: 52.93%
# Epoch: 31, Validation Accuracy: 54.01%
# Epoch: 32, Validation Accuracy: 53.36%
# Epoch: 33, Validation Accuracy: 53.76%
# Epoch: 34, Validation Accuracy: 53.16%
# Epoch: 35, Validation Accuracy: 54.63%
# Epoch: 36, Validation Accuracy: 53.26%
# Epoch: 37, Validation Accuracy: 54.44%
# Epoch: 38, Validation Accuracy: 54.78%
# Epoch: 39, Validation Accuracy: 54.70%
# Epoch: 40, Validation Accuracy: 54.77%
# Epoch: 41, Validation Accuracy: 55.80%
# Epoch: 42, Validation Accuracy: 55.30%
# Epoch: 43, Validation Accuracy: 55.51%
# Epoch: 44, Validation Accuracy: 55.61%
# Epoch: 45, Validation Accuracy: 55.53%
# Epoch: 46, Validation Accuracy: 55.66%
# Epoch: 47, Validation Accuracy: 55.80%
# Epoch: 48, Validation Accuracy: 56.35%
# Epoch: 49, Validation Accuracy: 55.40%
# Epoch: 50, Validation Accuracy: 56.58%
# Epoch: 51, Validation Accuracy: 56.16%
# Epoch: 52, Validation Accuracy: 56.13%
# Epoch: 53, Validation Accuracy: 56.10%
# Epoch: 54, Validation Accuracy: 55.85%
# Epoch: 55, Validation Accuracy: 56.32%
# Epoch: 56, Validation Accuracy: 56.52%
# Epoch: 57, Validation Accuracy: 56.38%
# Epoch: 58, Validation Accuracy: 56.39%
# Epoch: 59, Validation Accuracy: 56.53%
# Epoch: 60, Validation Accuracy: 56.73%
# Epoch: 61, Validation Accuracy: 56.41%
# Epoch: 62, Validation Accuracy: 56.85%
# Epoch: 63, Validation Accuracy: 56.73%
# Epoch: 64, Validation Accuracy: 56.07%
# Epoch: 65, Validation Accuracy: 56.53%
# Epoch: 66, Validation Accuracy: 56.14%
# Epoch: 67, Validation Accuracy: 56.33%
# Epoch: 68, Validation Accuracy: 56.96%
# Epoch: 69, Validation Accuracy: 57.26%
# Epoch: 70, Validation Accuracy: 57.07%
# Epoch: 71, Validation Accuracy: 56.91%
# Epoch: 72, Validation Accuracy: 56.97%
# Epoch: 73, Validation Accuracy: 57.25%
# Epoch: 74, Validation Accuracy: 56.93%
# Epoch: 75, Validation Accuracy: 57.23%
# Epoch: 76, Validation Accuracy: 57.18%
# Epoch: 77, Validation Accuracy: 57.29%
# Epoch: 78, Validation Accuracy: 57.23%
# Epoch: 79, Validation Accuracy: 57.05%
# Epoch: 80, Validation Accuracy: 57.21%
# Epoch: 81, Validation Accuracy: 57.01%
# Epoch: 82, Validation Accuracy: 57.11%
# Epoch: 83, Validation Accuracy: 56.85%
# Epoch: 84, Validation Accuracy: 57.15%
# Epoch: 85, Validation Accuracy: 57.33%
# Epoch: 86, Validation Accuracy: 57.12%
# Epoch: 87, Validation Accuracy: 57.44%
# Epoch: 88, Validation Accuracy: 57.20%
# Epoch: 89, Validation Accuracy: 57.11%
# Epoch: 90, Validation Accuracy: 57.28%
# Epoch: 91, Validation Accuracy: 57.26%
# Epoch: 92, Validation Accuracy: 57.20%
# Epoch: 93, Validation Accuracy: 57.19%
# Epoch: 94, Validation Accuracy: 57.14%
# Epoch: 95, Validation Accuracy: 57.06%
# Epoch: 96, Validation Accuracy: 57.11%
# Epoch: 97, Validation Accuracy: 57.28%
# Epoch: 98, Validation Accuracy: 57.32%
# Epoch: 99, Validation Accuracy: 57.29%
# Epoch: 100, Validation Accuracy: 57.27%

# %% [markdown]
# Please submit your best_model.pth with this notebook. And report the best test results you get.

# %% [markdown]
# **RESULTS**
# The best results my ViT model got was an accuracy of 57.44% on validation set.
